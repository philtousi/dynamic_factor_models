# %%
import pandas as pd
import numpy as np
import pandas_datareader as web
import datetime as dt
import random
import statsmodels.tsa.api as sm
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (11,5)
plt.rcParams['savefig.dpi'] = 300
from sklearn.metrics import mean_squared_error as mse
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# START = dt.datetime(2001, 11, 1)
# END = dt.datetime(2022, 11, 30)
# random.seed(61)

# %%
df = pd.read_csv('./LCDMA_October_2022/balanced_can_md.csv')
df = df.set_index(pd.DatetimeIndex(df['Date'])).iloc[200:,1:30]
df.describe()
# Out:
#           GDP_new     BSI_new     GPI_new     SPI_new      IP_new     NDM_new  \
# count  301.000000  301.000000  301.000000  301.000000  301.000000  301.000000
# mean     0.001831    0.001931    0.001236    0.002117    0.000928    0.000153
# std      0.009681    0.010649    0.012781    0.009206    0.013915    0.014389
# min     -0.113313   -0.125719   -0.145960   -0.099635   -0.138356   -0.138828
# 25%      0.000080   -0.000299   -0.002947    0.000937   -0.004802   -0.006497
# 50%      0.002148    0.002441    0.001422    0.002425    0.000996    0.000578
# 75%      0.004340    0.005049    0.007022    0.003763    0.008397    0.007829
# max      0.055065    0.062748    0.064830    0.058301    0.043393    0.052187
#
#            DM_new    OILP_new     CON_new      RT_new  ...  EMP_FIN_CAN  \
# count  301.000000  301.000000  301.000000  301.000000  ...   301.000000
# mean     0.000436    0.001475    0.002220    0.002435  ...     0.001468
# ...

# %%
num_oos=60
testset = df.iloc[-num_oos:]
iters=300

model = sm.DynamicFactorMQ(endog=df)
results = model.fit(maxiter=iters, disp=True)

dfm_pred = results.predict(start=df.shape[0]-num_oos, end=df.shape[0]-1)
# Out:
# EM start iterations, llf=-1.2423e+05
# EM iteration 2, llf=-1.2323e+05, convergence criterion=0.0081013
# EM iteration 3, llf=-1.2322e+05, convergence criterion=1.4402e-05
# EM iteration 4, llf=-1.2322e+05, convergence criterion=1.0956e-06
# EM iteration 5, llf=-1.2322e+05, convergence criterion=2.9265e-07
# EM converged at iteration 5, llf=-1.2322e+05, convergence criterion=2.9265e-07 < tolerance=1e-06

# %%
mse_gdp_in = mse(dfm_pred['GDP_new'], testset['GDP_new'])
mse_gdp_in
# Out:
# 0.00041995844188186135

# %%
plt.plot(dfm_pred['GDP_new'],  label='DFM')
plt.plot(testset['GDP_new'], label='Actual')
plt.legend()
plt.show()

# %%
h=1
dfm_forecast = pd.DataFrame()

model = sm.DynamicFactorMQ(endog=df)
results = model.fit(maxiter=iters, disp=False)

for i in range(-num_oos,0,h):

    results = results.apply(endog=df.iloc[:i]) # might be
    forecast = results.forecast(steps=h)
    dfm_forecast = pd.concat([dfm_forecast, forecast])

# %%
mse_gdp_oos = mse(dfm_forecast['GDP_new'], testset['GDP_new'])
mse_gdp_oos
# Out:
# MSE of DFM:  886787833.11553

# %%
plt.plot(dfm_forecast['GDP_new'],  label='DFM')
plt.plot(testset['GDP_new'], label='Actual')
plt.legend()
plt.show()

# %%
results = results.apply(df)
forecast = results.forecast(steps=h)
forecast
# Out:
#              GDP_new   BSI_new   GPI_new  SPI_new    IP_new   NDM_new  \
# 2022-10-01  0.001615  0.001624  0.000621  0.00201  0.000581  0.001053
#
#               DM_new  OILP_new   CON_new   RT_new  ...  TOT_HRS_CAN  \
# 2022-10-01 -0.001698  0.001295  0.000913  0.00183  ...     0.002628
#
#             GOOD_HRS_CAN  GOOD_OVT_HRS_CAN  NHOUSE_P_CAN  NHOUSE_P_NF  \
# 2022-10-01      0.004167          0.070178      0.000352     0.002945
#
#             NHOUSE_P_PEI  NHOUSE_P_NS  NHOUSE_P_NB  NHOUSE_P_QC  NHOUSE_P_ONT
# 2022-10-01      0.000907     0.002037     0.001282     0.001949      0.001076
#
# [1 rows x 39 columns]

# %%
pd.DataFrame(results.factors.smoothed/results.factors.smoothed.std(), index=df.index).plot(color=['c'])
plt.show()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Dynamic Factor Results
# ...
# Dep. Variable:      "GDP_new", and 38 more   No. Observations:                  301
# Model:                Dynamic Factor Model   Log Likelihood              -11295.782
#                    + 2 factors in 2 blocks   AIC                          22911.564
#                      + AR(1) idiosyncratic   BIC                          23504.701
# Date:                     Wed, 14 Dec 2022   HQIC                         23148.912
# Time:                             11:44:24
# Sample:                         09-01-1997
#                               - 09-01-2022
# Covariance Type:              Not computed
#                             Observation equation:
# ...
#     Factor loadings:          0          1    idiosyncratic: AR(1)        var.
# ------------------------------------------------------------------------------
# ...
